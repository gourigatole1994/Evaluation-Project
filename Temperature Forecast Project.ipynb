# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/refs/heads/main/temperature.csv')
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.tail()
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %%
#checking the Total No of Rows and Columns
df.shape
# Out:
# (7752, 25)

# %%
#checking the columns of datasets
df.columns.tolist()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
#checking the datatypes of columns
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
"""there is 2 different types of data float,object present in the dataset. """
# Out:
# 'there is 2 different types of data float,object present in the dataset. '

# %%
#converting the datatype of date column from object to datetime
df['Date']=pd.to_datetime(df["Date"], format = '%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   datetime64[ns]
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
#checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# station
# 1.0     310
# 14.0    310
# 24.0    310
# 23.0    310
# 22.0    310
# 21.0    310
# 20.0    310
# 19.0    310
# 18.0    310
# 17.0    310
# 16.0    310
# 15.0    310
# 13.0    310
# 2.0     310
# 12.0    310
# 11.0    310
# 10.0    310
# 9.0     310
# 8.0     310
# 7.0     310
# 6.0     310
# 5.0     310
# 4.0     310
# 3.0     310
# 25.0    310
# Name: count, dtype: int64
#
#
# Date
# 2013-06-30    25
# 2016-07-18    25
# 2016-07-25    25
# 2016-07-24    25
# 2016-07-23    25
#               ..
# 2014-08-09    25
# 2014-08-08    25
# 2014-08-07    25
# 2014-08-06    25
# 2017-08-30    25
# Name: count, Length: 310, dtype: int64
#
#
# Present_Tmax
# 31.4    112
# 29.4    111
# 29.1    108
# 29.7    107
# 31.9    105
#        ...
# 36.9      1
# 21.2      1
# 20.1      1
# 36.4      1
# 20.3      1
# Name: count, Length: 167, dtype: int64
#
#
# Present_Tmin
# 24.0    161
# 23.8    153
# 23.1    144
# 23.5    143
# 23.3    142
#        ...
# 13.6      1
# 14.2      1
# ...

# %%
#checking number of unique values in each column
df.nunique().to_frame("No of unique values")
# Out:
#                   No of unique values
# station                            25
# Date                              310
# Present_Tmax                      167
# Present_Tmin                      155
# LDAPS_RHmin                      7672
# LDAPS_RHmax                      7664
# LDAPS_Tmax_lapse                 7675
# LDAPS_Tmin_lapse                 7675
# LDAPS_WS                         7675
# LDAPS_LH                         7675
# LDAPS_CC1                        7569
# LDAPS_CC2                        7582
# LDAPS_CC3                        7599
# LDAPS_CC4                        7524
# LDAPS_PPT1                       2812
# LDAPS_PPT2                       2510
# LDAPS_PPT3                       2356
# LDAPS_PPT4                       1918
# lat                                12
# lon                                25
# DEM                                25
# Slope                              27
# Solar radiation                  1575
# Next_Tmax                         183
# ...

# %%
#checking for null values
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
#Fill null values Using mean method in contineous data 
for i in df.columns:
    if df.dtypes[i]=="float64":
        df[i]=df[i].fillna(df[i].mean())
        
#for date column using mode method fill null values
df['Date']=df['Date'].fillna(df['Date'].mode()[0])

# %%
#again checking for null values
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
#checking for duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
"""No Null Values and Duplicated Values in Dataset."""
# Out:
# 'No Null Values and Duplicated Values in Dataset.'

# %%
#statistical summary of numerical col
df.describe()
# Out:
#            station                           Date  Present_Tmax  Present_Tmin  \
# count  7752.000000                           7752   7752.000000   7752.000000
# mean     13.000000  2015-07-30 16:53:18.761609984     29.768211     23.225059
# min       1.000000            2013-06-30 00:00:00     20.000000     11.300000
# 25%       7.000000            2014-07-15 00:00:00     27.800000     21.700000
# 50%      13.000000            2015-07-30 00:00:00     29.900000     23.400000
# 75%      19.000000            2016-08-15 00:00:00     32.000000     24.900000
# max      25.000000            2017-08-30 00:00:00     37.600000     29.900000
# std       7.210637                            NaN      2.956557      2.403036
#
#        LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  \
# count  7752.000000  7752.000000       7752.000000       7752.000000
# mean     56.759372    88.374804         29.613447         23.512589
# ...

# %%
#Data Visualization 
plt.figure(figsize=(16,25))
p=1
for i in df:
    if p<=25:
        plt.subplot(5,5,p)
        sns.scatterplot(x='Next_Tmax',y=i,data=df,color='m')
        plt.xlabel("Next_Tmax")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
#Data Visualization 
plt.figure(figsize=(16,25))
p=1
for i in df:
    if p<=25:
        plt.subplot(5,5,p)
        sns.scatterplot(x='Next_Tmin',y=i,data=df,color='g')
        plt.xlabel("Next_Tmin")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
#here we drop Date column
df.drop(['Date'],axis=1,inplace=True)

# %%
#checking the outliers using boxplot
plt.figure(figsize=(10,8),facecolor="m")
plotnumber=1
for col in df:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.boxplot(df[col],palette="viridis_r")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
"""Here only station,LDAPS_RHmin,LDAPS_CC1,LDAPS_CC2,LDAPS_CC3,LDAPS_CC4,lat,lon,solar radiation have no outliers remaining
all columns have outliers. using zscore and IQR technique we can remove outliers"""
# Out:
# 'Here only station,LDAPS_RHmin,LDAPS_CC1,LDAPS_CC2,LDAPS_CC3,LDAPS_CC4,lat,lon,solar radiation have no outliers remaining\nall columns have outliers. using zscore and IQR technique we can remove outliers'

# %%
from scipy.stats import zscore
z_score=zscore(df[['Present_Tmax','Present_Tmin','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_LH','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','DEM','Slope','Next_Tmax','Next_Tmin']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
#after removing outliers
df.shape
# Out:
# (6894, 24)

# %%
"""Dataset contains 6894 rows with 24 columns"""
# Out:
# 'Dataset contains 6894 rows with 24 columns'

# %%
#Cheking For Skewness
#lets see how data is distributed for every column
plt.figure(figsize=(18,16),facecolor='m')
p=1
for col in df:
    if p<=24:
        ax=plt.subplot(6,4,p)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=10)
    p+=1
plt.show()

# %%
df.skew()
# Out:
# station             0.002792
# Present_Tmax       -0.272653
# Present_Tmin       -0.225479
# LDAPS_RHmin         0.305740
# LDAPS_RHmax        -0.688257
# LDAPS_Tmax_lapse   -0.109372
# LDAPS_Tmin_lapse   -0.382667
# LDAPS_WS            1.087781
# LDAPS_LH            0.568781
# LDAPS_CC1           0.593990
# LDAPS_CC2           0.500911
# LDAPS_CC3           0.700217
# LDAPS_CC4           0.710930
# LDAPS_PPT1          3.731226
# LDAPS_PPT2          4.843672
# LDAPS_PPT3          5.482625
# LDAPS_PPT4          5.927822
# lat                 0.108251
# lon                -0.275508
# DEM                 1.764031
# Slope               1.593600
# Solar radiation    -0.505353
# Next_Tmax          -0.270084
# Next_Tmin          -0.237767
# dtype: float64

# %%
#Using cube root method we can remove skewness
df['LDAPS_WS']=np.cbrt(df['LDAPS_WS'])
df['LDAPS_PPT1']=np.cbrt(df['LDAPS_PPT1'])
df['LDAPS_PPT2']=np.cbrt(df['LDAPS_PPT2'])
df['LDAPS_PPT3']=np.cbrt(df['LDAPS_PPT3'])
df['LDAPS_PPT4']=np.cbrt(df['LDAPS_PPT4'])
df['DEM']=np.cbrt(df['DEM'])
df['Slope']=np.cbrt(df['Slope'])

# %%
#again checking skewness
df.skew()
# Out:
# station             0.002792
# Present_Tmax       -0.272653
# Present_Tmin       -0.225479
# LDAPS_RHmin         0.305740
# LDAPS_RHmax        -0.688257
# LDAPS_Tmax_lapse   -0.109372
# LDAPS_Tmin_lapse   -0.382667
# LDAPS_WS            0.616390
# LDAPS_LH            0.568781
# LDAPS_CC1           0.593990
# LDAPS_CC2           0.500911
# LDAPS_CC3           0.700217
# LDAPS_CC4           0.710930
# LDAPS_PPT1          1.854774
# LDAPS_PPT2          2.242623
# LDAPS_PPT3          2.392493
# LDAPS_PPT4          2.714029
# lat                 0.108251
# lon                -0.275508
# DEM                 0.934952
# Slope               0.621552
# Solar radiation    -0.505353
# Next_Tmax          -0.270084
# Next_Tmin          -0.237767
# dtype: float64

# %%
#checking the correlation between features and target
cor=df.corr()
cor
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.109476      0.132092    -0.067901
# Present_Tmax      0.109476      1.000000      0.612869    -0.151799
# Present_Tmin      0.132092      0.612869      1.000000     0.150633
# LDAPS_RHmin      -0.067901     -0.151799      0.150633     1.000000
# LDAPS_RHmax      -0.172809     -0.295184     -0.038516     0.552690
# LDAPS_Tmax_lapse  0.065989      0.534696      0.434144    -0.555284
# LDAPS_Tmin_lapse  0.103741      0.609642      0.752887     0.131633
# LDAPS_WS          0.024778     -0.091263      0.027262     0.216195
# LDAPS_LH         -0.135588      0.129469     -0.003840    -0.037860
# LDAPS_CC1         0.009486     -0.286673      0.090553     0.575977
# LDAPS_CC2         0.006295     -0.155984      0.117494     0.714711
# LDAPS_CC3         0.007589     -0.059549      0.042697     0.656819
# LDAPS_CC4         0.011906     -0.049571     -0.005822     0.458909
# ...

# %%
#visualizing the correlation matrix by plotting heatmap
plt.figure(figsize=(16,12))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".1g",linecolor="black",annot=True)
plt.yticks(rotation=0);
plt.show()

# %%
"""From above observation we can see Present_Tmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse,Next_Tmin are positively related to 
target variable i.e Next_Tmax. Most of the other features are negatively correlated to target variable."""
# Out:
# 'From above observation we can see Present_Tmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse,Next_Tmin are positively related to \ntarget variable i.e Next_Tmax. Most of the other features are negatively correlated to target variable.'

# %%
#We can observe the positive and negative correlated features with the target
cor['Next_Tmax'].sort_values(ascending = False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.805676
# Present_Tmax        0.586403
# Next_Tmin           0.584859
# LDAPS_Tmin_lapse    0.538722
# Present_Tmin        0.446660
# LDAPS_LH            0.172888
# station             0.106116
# lon                 0.008040
# Solar radiation    -0.031431
# lat                -0.047190
# Slope              -0.088008
# DEM                -0.139498
# LDAPS_PPT4         -0.195674
# LDAPS_PPT3         -0.222631
# LDAPS_WS           -0.247376
# LDAPS_RHmax        -0.300434
# LDAPS_PPT1         -0.304729
# LDAPS_PPT2         -0.305635
# LDAPS_CC4          -0.420883
# LDAPS_RHmin        -0.428028
# LDAPS_CC1          -0.447965
# LDAPS_CC2          -0.478533
# LDAPS_CC3          -0.484693
# Name: Next_Tmax, dtype: float64

# %%
#separating features and label for the first Target Variable 'Next_Tmax'
x=df.drop("Next_Tmax",axis=1)
y=df["Next_Tmax"]

# %%
#Feature Scaling using Standard Scalarization
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0    -1.671954     -0.433615     -0.828471     0.191277     0.436386
# 1    -1.533039      0.687567     -0.741763    -0.242211     0.362340
# 2    -1.394124      0.582457     -0.004748    -0.500679    -0.597331
# 3    -1.255209      0.722604      0.038606     0.190127     1.213156
# 4    -1.116295      0.512383     -0.611702     0.040693     0.297274
# ...        ...           ...           ...          ...          ...
# 6889  1.106341     -2.395683     -2.389208    -2.236969    -1.424012
# 6890  1.245255     -2.605905     -2.562623    -1.845904    -0.638370
# 6891  1.384170     -2.325609     -2.692685    -2.088503    -1.335953
# 6892  1.523085     -2.325609     -2.432562    -2.283872    -1.563873
# 6893  1.661999     -2.360646     -2.562623    -2.363999    -1.571287
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %%
#Checking Variance Inflation Factor(VIF)
#finding variance inflation factor in each scaled col 
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) 
for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values          Features
# 0     1.244901           station
# 1     2.762346      Present_Tmax
# 2     3.303693      Present_Tmin
# 3     5.952049       LDAPS_RHmin
# 4     2.241667       LDAPS_RHmax
# 5     6.862234  LDAPS_Tmax_lapse
# 6     8.342933  LDAPS_Tmin_lapse
# 7     1.212507          LDAPS_WS
# 8     1.528243          LDAPS_LH
# 9     4.809488         LDAPS_CC1
# 10    5.400846         LDAPS_CC2
# 11    5.150204         LDAPS_CC3
# 12    3.011710         LDAPS_CC4
# 13    2.674295        LDAPS_PPT1
# 14    2.219512        LDAPS_PPT2
# 15    1.739809        LDAPS_PPT3
# 16    1.742851        LDAPS_PPT4
# 17    1.242600               lat
# 18    1.179109               lon
# 19    3.242532               DEM
# 20    2.907355             Slope
# 21    1.251851   Solar radiation
# 22    5.330464         Next_Tmin

# %%
"Here we can see VIF values < 10. Therefore, No Multicollinarity issue."
# Out:
# 'Here we can see VIF values < 10. Therefore, No Multicollinarity issue.'

# %%
# .....FINDING BEST RANDOM STATE
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
#creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is ",maxAccu,"on Random state",maxRs)
# Out:
# Maximum r2 score is  0.7932224726189931 on Random state 112

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_LR)))
# Out:
# R2_score: 0.7932224726189931
# R2_score on training data: 76.87873947241897
# Mean Absolute Error: 1.0063260324027505
# Mean Squared Error: 1.7526962364259386
# Root Mean Squared Error: 1.0031580296258165

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.8982932595961083
# R2_score on training data: 98.45133151693682
# Mean Absolute Error: 0.6926907710675103
# Mean Squared Error: 0.8620908828094668
# Root Mean Squared Error: 0.8322804641871094

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)

print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error:',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.5529063914978648
# R2_score on training data: 52.283609218211616
# Mean Absolute Error: 1.538120926970821
# Mean Squared Error: 3.7896733502760815
# Root Mean Squared Error: 1.240210033409995

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)

print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error:',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_rd)))
# Out:
# R2_score: 0.7932071005948721
# R2_score on training data: 76.8787249125704
# Mean Absolute Error: 1.0063630954946832
# Mean Squared Error: 1.752826533413065
# Root Mean Squared Error: 1.0031765026627584

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print(knn)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:',mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_knn)))
# Out:
# KNeighborsRegressor()
# R2_score: 0.8982932595961083
# R2_score on training data: 89.96565455754006
# Mean Absolute Error: 0.8543968043009786
# Mean Squared Error: 1.2741039187475038
# Root Mean Squared Error: 0.9243358720189208

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print(dtr)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_dtr)))
# Out:
# DecisionTreeRegressor()
# R2_score: 0.7525513834215256
# R2_score on training data: 100.0
# Mean Absolute Error: 1.040951538906284
# Mean Squared Error: 2.0974342061202833
# Root Mean Squared Error: 1.0202703263872197

# %%
from sklearn.ensemble import GradientBoostingRegressor
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print(GBR)
print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_score: 0.8540491485131309
# R2_score on training data: 86.75214530097786
# Mean Absolute Error: 0.8490749467252072
# Mean Squared Error: 1.2371146485026274
# Root Mean Squared Error: 0.9214526285844581

# %%
#cross validation score
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.73458645 0.67565035 0.68299357 0.74468715 0.68195268]
# 0.703974038543922
# Difference between R2 score and cross validation score is : 8.92484340750711

# %%
score1=cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [0.71565267 0.66447729 0.66374965 0.7203469  0.65193998]
# 0.6832332973514672
# Difference between R2 score and cross validation score is : 21.50599622446411

# %%
score2=cross_val_score(lasso,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_lasso)-score2.mean())*100)
# Out:
# [0.46478184 0.46224007 0.55792057 0.36847068 0.52126513]
# 0.47493565788398867
# Difference between R2 score and cross validation score is : 7.797073361387613

# %%
score4=cross_val_score(rd,x,y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score4.mean())*100)
# Out:
# [0.73473016 0.67565566 0.68294735 0.74472358 0.68198465]
# 0.7040082788023269
# Difference between R2 score and cross validation score is : 8.919882179254524

# %%
score5=cross_val_score(knn,x,y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score5.mean())*100)
# Out:
# [0.64581683 0.48556109 0.5141012  0.63176444 0.58412182]
# 0.5722730774343824
# Difference between R2 score and cross validation score is : 22.093402316048973

# %%
score6=cross_val_score(dtr,x,y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score6.mean())*100)
# Out:
# [0.36222966 0.40660594 0.42752456 0.55404404 0.45252491]
# 0.4405858233488962
# Difference between R2 score and cross validation score is : 35.26212772459759

# %%
score7=cross_val_score(GBR,x,y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score7.mean())*100)
# Out:
# [0.68434737 0.66273489 0.67624189 0.76915449 0.66403384]
# 0.6913024970525303
# Difference between R2 score and cross validation score is : 10.190460354234176

# %%
"""From the difference between both R2 score and cross validation score computed on R2 score we 
can conclude that Ridge Regression as our best fitting and best performing model"""
# Out:
# 'From the difference between both R2 score and cross validation score computed on R2 score we \ncan conclude that Ridge Regression as our best fitting and best performing model'

# %%
#Hyper parameter tunning
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,0.05,0.4,2],'fit_intercept':[True,False],
      'solver':['auto','svd','cholesky','lsqr','sag','saga','lbfgs'],
      'positive':[False,True],
      'random_state':range(1,30),
      
      }
gscv=GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': range(1, 30),
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 17,
#  'solver': 'saga'}

# %%
model=Ridge(alpha=2,fit_intercept=True,positive=False,random_state=17,solver='saga')

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred)))
# Out:
# R2_score: 0.7931893372763412
# Mean Absolute Error: 1.006406947491555
# Mean Squared Error: 1.7529770995888474
# Root Mean Squared Error: 1.003198358995645

# %%
import joblib
import pickle
filename='Next_Tmax.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Next_Tmax.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 79.31893372763412

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  30.069328  29.650819  32.812901  30.403489  24.231646  28.168112
# Original   27.200000  29.300000  32.000000  31.600000  25.200000  27.200000
#
#                 6          7          8          9     ...       1714  \
# Predicted  31.719298  36.879057  26.039165  34.916787  ...  33.662639
# Original   33.600000  36.800000  25.100000  35.600000  ...  33.500000
#
#                 1715       1716       1717       1718       1719       1720  \
# Predicted  29.450142  28.715733  29.652008  30.908931  36.231626  29.529647
# Original   28.600000  28.900000  29.600000  30.900000  34.700000  30.300000
#
#                 1721       1722       1723
# Predicted  28.400922  29.139112  29.986681
# Original   28.500000  30.200000  32.700000
#
# [2 rows x 1724 columns]

# %%
"""Now Taking Next_Tmin as Target"""
# Out:
# 'Now Taking Next_Tmin as Target'

# %%
#dividing data into x and y
#separating features and label
x=df.drop("Next_Tmin",axis=1)
y=df["Next_Tmin"]

# %%
#Feature Scaling using Standard Scalarization
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0    -1.671954     -0.433615     -0.828471     0.191277     0.436386
# 1    -1.533039      0.687567     -0.741763    -0.242211     0.362340
# 2    -1.394124      0.582457     -0.004748    -0.500679    -0.597331
# 3    -1.255209      0.722604      0.038606     0.190127     1.213156
# 4    -1.116295      0.512383     -0.611702     0.040693     0.297274
# ...        ...           ...           ...          ...          ...
# 6889  1.106341     -2.395683     -2.389208    -2.236969    -1.424012
# 6890  1.245255     -2.605905     -2.562623    -1.845904    -0.638370
# 6891  1.384170     -2.325609     -2.692685    -2.088503    -1.335953
# 6892  1.523085     -2.325609     -2.432562    -2.283872    -1.563873
# 6893  1.661999     -2.360646     -2.562623    -2.363999    -1.571287
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %%
#Checking Variance Inflation Factor(VIF)
#finding variance inflation factor in each scaled col 
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) 
for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values          Features
# 0     1.254193           station
# 1     2.827975      Present_Tmax
# 2     3.016853      Present_Tmin
# 3     5.908359       LDAPS_RHmin
# 4     2.244870       LDAPS_RHmax
# 5     7.990342  LDAPS_Tmax_lapse
# 6     6.807331  LDAPS_Tmin_lapse
# 7     1.234086          LDAPS_WS
# 8     1.554991          LDAPS_LH
# 9     4.829427         LDAPS_CC1
# 10    5.393027         LDAPS_CC2
# 11    5.164948         LDAPS_CC3
# 12    3.089833         LDAPS_CC4
# 13    2.675411        LDAPS_PPT1
# 14    2.206696        LDAPS_PPT2
# 15    1.738959        LDAPS_PPT3
# 16    1.755288        LDAPS_PPT4
# 17    1.240773               lat
# 18    1.185794               lon
# 19    3.119804               DEM
# 20    2.866589             Slope
# 21    1.253302   Solar radiation
# 22    3.927599         Next_Tmax

# %%
"Here we can see VIF values < 10. Therefore, No Multicollinarity issue."
# Out:
# 'Here we can see VIF values < 10. Therefore, No Multicollinarity issue.'

# %%
# .....FINDING BEST RANDOM STATE
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
#creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is ",maxAccu,"on Random state",maxRs)
# Out:
# Maximum r2 score is  0.8500270338204748 on Random state 194

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_LR)))
# Out:
# R2_score: 0.8500270338204748
# R2_score on training data: 82.82684344093096
# Mean Absolute Error: 0.7515137600238979
# Mean Squared Error: 0.8839679036541389
# Root Mean Squared Error: 0.8668989329927094

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.9101697976869841
# R2_score on training data: 98.50962161917657
# Mean Absolute Error: 0.5563248624032319
# Mean Squared Error: 0.5294755291324279
# Root Mean Squared Error: 0.7458718806894599

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)

print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error:',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.576390354892696
# R2_score on training data: 57.38514382682369
# Mean Absolute Error: 1.2638485701408189
# Mean Squared Error: 2.4968321924428234
# Root Mean Squared Error: 1.124210198379653

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)

print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error:',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_rd)))
# Out:
# R2_score: 0.850024780827276
# R2_score on training data: 82.82683528592281
# Mean Absolute Error: 0.7515169234977562
# Mean Squared Error: 0.8839811832052852
# Root Mean Squared Error: 0.8669007575828713

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print(knn)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:',mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_knn)))
# Out:
# KNeighborsRegressor()
# R2_score: 0.9101697976869841
# R2_score on training data: 91.06633020431943
# Mean Absolute Error: 0.6527529069898409
# Mean Squared Error: 0.7407408068556754
# Root Mean Squared Error: 0.8079312514006627

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print(dtr)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_dtr)))
# Out:
# DecisionTreeRegressor()
# R2_score: 0.7871205389204022
# R2_score on training data: 100.0
# Mean Absolute Error: 0.8294102899105715
# Mean Squared Error: 1.2547502108899788
# Root Mean Squared Error: 0.9107196549490801

# %%
#cross validation score
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.74023853 0.67763033 0.79968641 0.84373076 0.85387063]
# 0.7830313306733796
# Difference between R2 score and cross validation score is : 6.699570314709524

# %%
score1=cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [0.73523248 0.69496929 0.81083867 0.84609949 0.84545714]
# 0.7865194119543355
# Difference between R2 score and cross validation score is : 12.365038573264863

# %%
score2=cross_val_score(lasso,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_lasso)-score2.mean())*100)
# Out:
# [0.54050919 0.38867869 0.56322981 0.45491069 0.62810583]
# 0.5150868427906639
# Difference between R2 score and cross validation score is : 6.1303512102032105

# %%
score3=cross_val_score(rd,x,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score3.mean())*100)
# Out:
# [0.7402696  0.67769555 0.79966529 0.84375214 0.85388408]
# 0.7830533310706198
# Difference between R2 score and cross validation score is : 6.697144975665614

# %%
score4=cross_val_score(knn,x,y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score4.mean())*100)
# Out:
# [0.52089287 0.50852781 0.67927791 0.69504799 0.77145254]
# 0.6350398247252788
# Difference between R2 score and cross validation score is : 21.49849561019972

# %%
score5=cross_val_score(dtr,x,y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score5.mean())*100)
# Out:
# [0.49638464 0.48399018 0.63691535 0.72104204 0.65749749]
# 0.5991659400030805
# Difference between R2 score and cross validation score is : 25.08588408241954

# %%
"""From the difference between both R2 score and cross validation score computed on R2 score we 
can conclude that Random Forest Regressor is our best fitting and best performing model"""
# Out:
# 'From the difference between both R2 score and cross validation score computed on R2 score we \ncan conclude that Random Forest Regressor is our best fitting and best performing model'

# %%
#Hyper parameter tunning
from sklearn.model_selection import GridSearchCV

# %%
param = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

gscv=GridSearchCV(RFR,param_grid=param,n_jobs=-1, cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
gscv.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 30}

# %%
model=RandomForestRegressor(bootstrap=False,max_features='sqrt',n_estimators=30,min_samples_split=2)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred)))
# Out:
# R2_score: 0.9193072318333876
# Mean Absolute Error: 0.5293062727607207
# Mean Squared Error: 0.47561783255593154
# Root Mean Squared Error: 0.727534379091958

# %%
import joblib
import pickle
filename='Next_Tmin.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Next_Tmin.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 91.93072318333876

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#             0          1          2          3          4          5     \
# Predicted  20.84  18.773333  22.426667  24.453333  24.176667  24.216667
# Original   19.80  18.400000  21.600000  24.800000  25.000000  23.700000
#
#                 6          7          8          9     ...       1714  \
# Predicted  19.876667  25.863333  22.693333  24.633333  ...  24.823333
# Original   19.800000  27.500000  23.200000  25.100000  ...  23.900000
#
#                 1715       1716   1717   1718   1719       1720       1721  \
# Predicted  20.766667  20.943333  23.18  25.63  26.22  25.376667  21.056667
# Original   21.900000  20.900000  23.90  26.00  25.30  25.800000  20.800000
#
#                 1722       1723
# Predicted  19.703333  21.363333
# Original   18.900000  21.000000
#
# [2 rows x 1724 columns]

# %%
>>From the difference between both R2 score and cross validation score computed on R2 score we can conclude that 
  Ridge Regression is our best fitting and best performing model
>>The best score is 79.31% for prediction of Next Day Maximum Temperature. 
                        AND
>>From the difference between both R2 score and cross validation score computed on R2 score we can conclude that 
  Random Forest Regressor is our best fitting and best performing model
>>The best score is 91.93% for prediction of Next Day Minimum Temperature.
