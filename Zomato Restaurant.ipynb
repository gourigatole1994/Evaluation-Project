# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('https://github.com/dsrscientist/dataset4/raw/refs/heads/main/zomato.csv', encoding="cp1251")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlЫ± Gurme           208  ЫБstanbul
# 9547        5908749             Ceviz AЫфacЫ±           208  ЫБstanbul
# 9548        5915807                     Huqqa           208  ЫБstanbul
# 9549        5916112              AЃфЃфk Kahve           208  ЫБstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ЫБstanbul
#
#                                                 Address     Locality  \
# 9546  KemankeЃф Karamustafa PaЃфa Mahallesi, RЫ±htЫ±...     Karakн_y
# 9547  KoЃфuyolu Mahallesi, Muhittin нмstн_ndaЫф Cadd...    KoЃфuyolu
# 9548  Kuruн_eЃфme Mahallesi, Muallim Naci Caddesi, N...  Kuruн_eЃфme
# 9549  Kuruн_eЃфme Mahallesi, Muallim Naci Caddesi, N...  Kuruн_eЃфme
# 9550  CafeaЫфa Mahallesi, BademaltЫ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakн_y, ЫБstanbul  28.977392  41.022793
# ...

# %%
#checking the rows and columns
df.shape
# Out:
# (9551, 21)

# %%
#checking null values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
"Here we can see the null values present in cuisines column, so using mode method we can remove null values."
# Out:
# 'Here we can see the null values present in cuisines column, so using mode method we can remove null values.'

# %%
#Remove Null values using mode method for categorical data
df['Cuisines']=df['Cuisines'].fillna(df['Cuisines'].mode()[0])

# %%
#again checking null values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#checking for duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
#checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Restaurant ID
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: count, Length: 9551, dtype: int64
#
#
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: count, Length: 7446, dtype: int64
#
#
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: count, dtype: int64
#
#
# City
# New Delhi           5473
# Gurgaon             1118
# ...

# %%
#checking no of unique values in each col
df.nunique().to_frame("No of unique values")
# Out:
#                       No of unique values
# Restaurant ID                        9551
# Restaurant Name                      7446
# Country Code                           15
# City                                  141
# Address                              8918
# Locality                             1208
# Locality Verbose                     1265
# Longitude                            8120
# Latitude                             8677
# Cuisines                             1825
# Average Cost for two                  140
# Currency                               12
# Has Table booking                       2
# Has Online delivery                     2
# Is delivering now                       2
# Switch to order menu                    1
# Price range                             4
# Aggregate rating                       33
# Rating color                            6
# Rating text                             6
# Votes                                1012

# %%
# removing column switch to order menu because it having one unique value
df.drop(['Switch to order menu'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (9551, 20)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
"""Here we dropping unnecessary columns. we keep Locality column and drop the address,locality verbose column because it 
contains description of locality column. And rating color is not important."""
# Out:
# 'Here we dropping unnecessary columns. we keep Locality column and drop the address,locality verbose column because it \ncontains description of locality column. And rating color is not important.'

# %%
df.drop(['Address','Locality Verbose','Rating color'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (9551, 17)

# %%
#DATA VISUALIZATION
#visualized the Top 20 famous restaurants
plt.figure(figsize=(12,6))
ax =df['Restaurant Name'].value_counts()[:20]
sns.barplot(x=ax,y=ax.index)
plt.xlabel('No of Restaurants')
plt.ylabel('Name of Restaurant')
plt.title("Top 20 Most famous Restaurants", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 20 Most famous Restaurants')

# %%
#visualized the count of online delivery
ax=sns.countplot(x='Has Online delivery',data=df)
print(df['Has Online delivery'].value_counts())
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
"Here we can see the Most of restaurants deliver offline."
# Out:
# 'Here we can see the Most of restaurants deliver offline.'

# %%
#visualized the count of Table booking
ax=sns.countplot(x='Has Table booking',data=df)
print(df['Has Table booking'].value_counts())
# Out:
# Has Table booking
# No     8393
# Yes    1158
# Name: count, dtype: int64

# %%
"From above observation we can say most of the restaurants is not allowed for table booking."
# Out:
# 'From above observation we can say most of the restaurants is not allowed for table booking.'

# %%
#visualized the count of rating text
ax=sns.countplot(x='Rating text',data=df)
print(df['Rating text'].value_counts())
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
"Most of the restaurants are Average rating."
# Out:
# 'Most of the restaurants are Average rating.'

# %%
#visualized the Top 20 Cuisines 
plt.figure(figsize=(12,6))
ax =df['Cuisines'].value_counts()[:20]
sns.barplot(x=ax,y=ax.index)
plt.xlabel('No of Counts')
plt.ylabel('Name of Cuisines')
plt.title("Top 20 Most Like Cuisines", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 20 Most Like Cuisines')

# %%
plt.figure(figsize=(6,4))
sns.distplot(df['Price range'])
plt.show()

# %%
plt.figure(figsize=(8,3))
ax =df.Locality.value_counts()[:20].plot(kind='bar')
plt.title('Number of Restaurants in given location', weight='bold')
plt.xlabel('Area')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
#visualized the average cost for two person
plt.figure(figsize=(8,8))
ax = df['Average Cost for two'].value_counts()[:20]
plt.pie(ax, labels=ax.index, autopct='%.2f')
plt.title('Average cost for two person(in %)')
plt.show()

# %%
"""From above observations we can see There is 11.10% chances for two person average cost will be 500, 11.06% chances for two
person average cost will be 300 and so on."""
# Out:
# 'From above observations we can see There is 11.10% chances for two person average cost will be 500, 11.06% chances for two\nperson average cost will be 300 and so on.'

# %%
#price range vs city
ax=plt.subplots(figsize=(16,8))
p= sns.barplot(x=df["Country Code"], y=df["Price range"], data=df)
p.set_xticklabels(p.get_xticklabels())
plt.title('Price range according to the Country code')
plt.show()

# %%
"Here we can see the price range in Country code 166,184,189(Qatar,Singapore,South Africa) is higher than the other countries. "
# Out:
# 'Here we can see the price range in Country code 166,184,189(Qatar,Singapore,South Africa) is higher than the other countries. '

# %%
#No of restaurants that providing online delivery or not
plt.figure(figsize = (10,4))
sns.countplot(x=df['Price range'], hue = df['Has Online delivery'])
plt.ylabel("No of Rest that providing online delivery or Not")
plt.title("Price range Vs online delivery")
# Out:
# Text(0.5, 1.0, 'Price range Vs online delivery')

# %%
#separating numerical and categorical columns

#checking for categorical column

cat=list(df.select_dtypes(include='object'))
print("Categorical columns: ",cat)
print("\n")

#checking for numerical columns
num=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        num.append(i)
print("numerical columns: ",num)
print("\n")
# Out:
# Categorical columns:  ['Restaurant Name', 'City', 'Locality', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Rating text']
#
#
# numerical columns:  ['Restaurant ID', 'Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
#checking the outliers using boxplot
plt.figure(figsize=(10,8),facecolor="Yellow")
plotnumber=1
for col in num:
    if plotnumber<=8:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(df[col],palette="viridis_r")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
"""Here we can see the outliers are present in all numerical columns so using Zscore and IQR technique we can remove outliers"""
# Out:
# 'Here we can see the outliers are present in all numerical columns so using Zscore and IQR technique we can remove outliers'

# %%
from scipy.stats import zscore
z_score=zscore(df[['Country Code','Longitude','Latitude','Average Cost for two','Price range','Aggregate rating','Votes']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
#after removing outliers
df.shape
# Out:
# (8565, 17)

# %%
"""Now, Dataset contains 8565 rows with 17 columns"""
# Out:
# 'Now, Dataset contains 8565 rows with 17 columns'

# %%
#encoding categorical cols using LabelEncoder

from sklearn.preprocessing import LabelEncoder
lab_enc=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=lab_enc.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Locality  \
# 0           6317637             3321           162    27        98
# 1           6304287             2794           162    27       376
# 2           6300002             2550           162    28       185
# 3           6318506             4150           162    28       549
# 4           6314302             4878           162    28       549
# ...             ...              ...           ...   ...       ...
# 9432        6201972             1947           166    13       717
# 9433        6201130             6352           166    13       736
# 9434       18261203             4824           166    13       742
# 9435        6201360             4253           166    13       759
# 9436       18318801             4767           166    13       759
#
#        Longitude   Latitude  Cuisines  Average Cost for two  Currency  \
# 0     121.027535  14.565443       657                  1100         0
# ...

# %%
#Cheking For Skewness
#lets see how data is distributed for every column
plt.figure(figsize=(18,16),facecolor='m')
p=1
for col in df:
    if p<=17:
        ax=plt.subplot(5,4,p)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=10)
    p+=1
plt.show()

# %%
df.skew()
# Out:
# Restaurant ID            0.117936
# Restaurant Name          0.050428
# Country Code            11.593933
# City                    -1.381151
# Locality                -0.175206
# Longitude               -3.529965
# Latitude                -3.180873
# Cuisines                -0.262894
# Average Cost for two     3.718671
# Currency                -1.193208
# Has Table booking        2.275670
# Has Online delivery      1.000376
# Is delivering now       15.779828
# Price range              1.029231
# Aggregate rating        -0.877262
# Rating text              0.431465
# Votes                    3.653843
# dtype: float64

# %%
"""The skewness present in almost all columns. but we can remove skewness in only numeric data not from categorical data.
so, using cube root method we can remove skewness."""
# Out:
# 'The skewness present in almost all columns. but we can remove skewness in only numeric data not from categorical data.\nso, using cube root method we can remove skewness.'

# %%
#Using cube root method we can remove skewness
df['Country Code']=np.cbrt(df['Country Code'])
df['Longitude']=np.cbrt(df['Longitude'])
df['Latitude']=np.cbrt(df['Latitude'])
df['Average Cost for two']=np.cbrt(df['Average Cost for two'])
df['Price range']=np.cbrt(df['Price range'])
df['Aggregate rating']=np.cbrt(df['Aggregate rating'])
df['Votes']=np.cbrt(df['Votes'])

# %%
#again checking skewness
df.skew()
# Out:
# Restaurant ID            0.117936
# Restaurant Name          0.050428
# Country Code            11.542592
# City                    -1.381151
# Locality                -0.175206
# Longitude               -3.765128
# Latitude                -3.596442
# Cuisines                -0.262894
# Average Cost for two     1.044058
# Currency                -1.193208
# Has Table booking        2.275670
# Has Online delivery      1.000376
# Is delivering now       15.779828
# Price range              0.614188
# Aggregate rating        -1.122575
# Rating text              0.431465
# Votes                    0.761689
# dtype: float64

# %%
#checking the correlation between features and target
cor=df.corr()
cor
# Out:
#                       Restaurant ID  Restaurant Name  Country Code      City  \
# Restaurant ID              1.000000         0.002933      0.037500  0.010785
# Restaurant Name            0.002933         1.000000      0.012263  0.008530
# Country Code               0.037500         0.012263      1.000000  0.022649
# City                       0.010785         0.008530      0.022649  1.000000
# Locality                   0.090610         0.008659     -0.029070 -0.029670
# Longitude                 -0.163732         0.015087      0.041061  0.024256
# Latitude                  -0.161499         0.013813     -0.087913  0.026483
# Cuisines                  -0.059961         0.060831     -0.020453  0.014873
# Average Cost for two      -0.141544         0.058539     -0.025576 -0.084334
# Currency                  -0.007135         0.000797     -0.212243 -0.134651
# Has Table booking         -0.090548         0.041460      0.028481 -0.002165
# ...

# %%
#visualizing the correlation matrix by plotting heatmap
plt.figure(figsize=(16,12))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".1g",linecolor="black",annot=True)
plt.yticks(rotation=0);
plt.show()

# %%
"""If we take 'Price range' as Target then we can see Average cost for two,Has Table booking,Votes are positively 
related to the Price range and features latitude,currency,locality,city,resturant id is negatively related to the target.
And If we take 'Average cost for two' as Target then we can see Price range,Has table booking,votes,Aggregate rating,has 
online delivery are positively related to target and country code,currency,locality,city,restaurant id is negatively
related to the Average cost for two."""
# Out:
# "If we take 'Price range' as Target then we can see Average cost for two,Has Table booking,Votes are positively \nrelated to the Price range and features latitude,currency,locality,city,resturant id is negatively related to the target.\nAnd If we take 'Average cost for two' as Target then we can see Price range,Has table booking,votes,Aggregate rating,has \nonline delivery are positively related to target and country code,currency,locality,city,restaurant id is negatively\nrelated to the Average cost for two."

# %%
#We can observe the positive and negative correlated features with the target
cor['Price range'].sort_values(ascending = False)
# Out:
# Price range             1.000000
# Average Cost for two    0.861018
# Has Table booking       0.546612
# Votes                   0.529663
# Aggregate rating        0.367788
# Country Code            0.163455
# Has Online delivery     0.162643
# Rating text             0.082879
# Restaurant Name         0.065204
# Longitude               0.043235
# Is delivering now       0.024281
# Cuisines                0.023799
# Latitude               -0.005251
# Currency               -0.028523
# Locality               -0.103064
# City                   -0.115992
# Restaurant ID          -0.145044
# Name: Price range, dtype: float64

# %%
#We can observe the positive and negative correlated features with the target
cor['Average Cost for two'].sort_values(ascending = False)
# Out:
# Average Cost for two    1.000000
# Price range             0.861018
# Has Table booking       0.617158
# Votes                   0.514683
# Aggregate rating        0.359413
# Has Online delivery     0.164124
# Rating text             0.065770
# Restaurant Name         0.058539
# Longitude               0.056887
# Latitude                0.043492
# Is delivering now       0.024454
# Cuisines                0.002598
# Country Code           -0.025576
# Currency               -0.065826
# Locality               -0.073840
# City                   -0.084334
# Restaurant ID          -0.141544
# Name: Average Cost for two, dtype: float64

# %%
#separating features and label for the first Target Variable 'Price range'
x=df.drop("Price range",axis=1)
y=df["Price range"]

# %%
#Feature Scaling using Standard Scalarization
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City  Locality  \
# 0         -0.277386         0.052689     11.390428 -0.498280 -1.603037
# 1         -0.278877        -0.226145     11.390428 -0.498280 -0.280920
# 2         -0.279356        -0.355245     11.390428 -0.381656 -1.189281
# 3         -0.277289         0.491312     11.390428 -0.381656  0.541836
# 4         -0.277759         0.876496     11.390428 -0.381656  0.541836
# ...             ...              ...           ...       ...       ...
# 8560      -0.290304        -0.674292     11.505165 -2.131029  1.340813
# 8561      -0.290398         1.656387     11.505165 -2.131029  1.431174
# 8562       1.056489         0.847925     11.505165 -2.131029  1.459708
# 8563      -0.290372         0.545809     11.505165 -2.131029  1.540557
# 8564       1.062922         0.817766     11.505165 -2.131029  1.540557
#
#       Longitude  Latitude  Cuisines  Average Cost for two   Currency  \
# ...

# %%
#Checking Variance Inflation Factor(VIF)
#finding variance inflation factor in each scaled col 
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) 
for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values              Features
# 0     1.435640         Restaurant ID
# 1     1.009145       Restaurant Name
# 2     1.435424          Country Code
# 3     1.050495                  City
# 4     1.038787              Locality
# 5    32.539408             Longitude
# 6    32.775508              Latitude
# 7     1.022529              Cuisines
# 8     2.026458  Average Cost for two
# 9     1.330509              Currency
# 10    1.667125     Has Table booking
# 11    1.220822   Has Online delivery
# 12    1.015060     Is delivering now
# 13    3.350026      Aggregate rating
# 14    1.874801           Rating text
# 15    3.575019                 Votes

# %%
"""Here we can see the multicollinearity issue. VIF values of Longitude and Latitude >10 therefore we need to drop one column
which have the greater VIF values. so we dropping Latitude feature here."""
# Out:
# 'Here we can see the multicollinearity issue. VIF values of Longitude and Latitude >10 therefore we need to drop one column\nwhich have the greater VIF values. so we dropping Latitude feature here.'

# %%
x.drop("Latitude",axis=1,inplace=True)

# %%
#Again checking vif values to confirm wether the multicollinearity still exists or not
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) 
for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values              Features
# 0     1.430434         Restaurant ID
# 1     1.009140       Restaurant Name
# 2     1.085765          Country Code
# 3     1.046700                  City
# 4     1.038695              Locality
# 5     1.065905             Longitude
# 6     1.022439              Cuisines
# 7     2.026221  Average Cost for two
# 8     1.078196              Currency
# 9     1.651070     Has Table booking
# 10    1.198193   Has Online delivery
# 11    1.014982     Is delivering now
# 12    3.345045      Aggregate rating
# 13    1.858971           Rating text
# 14    3.499416                 Votes

# %%
"Now No multicollinearity Issues."
# Out:
# 'Now No multicollinearity Issues.'

# %%
# .....FINDING BEST RANDOM STATE
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
#creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is ",maxAccu,"on Random state",maxRs)
# Out:
# Maximum r2 score is  0.8042844804716297 on Random state 123

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_LR)))
# Out:
# R2_score: 0.8007979190354857
# R2_score on training data: 78.68700920031077
# Mean Absolute Error: 0.06910775452465624
# Mean Squared Error: 0.006935794343931429
# Root Mean Squared Error: 0.2628835379491387

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.9891401173239763
# R2_score on training data: 99.85537662593448
# Mean Absolute Error: 0.004008396608075355
# Mean Squared Error: 0.0003781181023582852
# Root Mean Squared Error: 0.06331189941926679

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)

print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error:',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_rd)))
# Out:
# R2_score: 0.8007986948824355
# R2_score on training data: 78.6870059075294
# Mean Absolute Error: 0.06911003354457552
# Mean Squared Error: 0.0069357673305846775
# Root Mean Squared Error: 0.26288787257037083

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print(dtr)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_dtr)))
# Out:
# DecisionTreeRegressor()
# R2_score: 0.9787429650008475
# R2_score on training data: 100.0
# Mean Absolute Error: 0.0036422565328596453
# Mean Squared Error: 0.0007401249143684336
# Root Mean Squared Error: 0.06035111045258111

# %%
#Cross validation score
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.1584187   0.81034546  0.77128637  0.78901353 -0.15671969]
# 0.4744688725558993
# Difference between R2 score and cross validation score is : 32.63290464795864

# %%
score1=cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [0.71621883 0.97469703 0.99993355 0.99984137 0.921643  ]
# 0.922466753990871
# Difference between R2 score and cross validation score is : 6.667336333310536

# %%
score2=cross_val_score(rd,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score2.mean())*100)
# Out:
# [ 0.23356798  0.81033738  0.771286    0.78905547 -0.14867959]
# 0.4911134479856226
# Difference between R2 score and cross validation score is : 30.96852468968129

# %%
score3=cross_val_score(dtr,x,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_rd)-score3.mean())*100)
# Out:
# [-0.29955286  0.96224636  0.99854667  0.99886303  0.95486445]
# 0.7229935289877844
# Difference between R2 score and cross validation score is : 7.780516589465114

# %%
"""From the difference between both R2 score and cross validation score computed on R2 score we 
can conclude that RandomForestRegressor as our best fitting and best performing model"""
# Out:
# 'From the difference between both R2 score and cross validation score computed on R2 score we \ncan conclude that RandomForestRegressor as our best fitting and best performing model'

# %%
#Hyper parameter tunning
from sklearn.model_selection import GridSearchCV
param = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

gscv=GridSearchCV(RFR,param_grid=param,n_jobs=-1, cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
gscv.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'log2',
#  'min_samples_split': 4,
#  'n_estimators': 20}

# %%
model=RandomForestRegressor(bootstrap=False,max_features='log2',n_estimators=20,min_samples_split=4)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred)))
# Out:
# R2_score: 0.9755551517989446
# Mean Absolute Error: 0.013822528188326102
# Mean Squared Error: 0.0008511178149858021
# Root Mean Squared Error: 0.1175692484807405

# %%
import joblib
import pickle
filename='Price range.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Price range.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 97.55551517989446

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#            0         1     2         3     4     5         6     7     \
# Predicted   1.0  1.259921   1.0  1.259080   1.0   1.0  1.551113   1.0
# Original    1.0  1.259921   1.0  1.259921   1.0   1.0  1.587401   1.0
#
#                8         9     ...  2132      2133      2134      2135  2136  \
# Predicted  1.025992  1.462813  ...   1.0  1.417761  1.369879  1.490456   1.0
# Original   1.000000  1.442250  ...   1.0  1.587401  1.259921  1.587401   1.0
#
#            2137  2138      2139      2140      2141
# Predicted   1.0   1.0  1.411183  1.246925  1.252383
# Original    1.0   1.0  1.442250  1.259921  1.259921
#
# [2 rows x 2142 columns]

# %%
"......Now Taking 'Average Cost for two' as Target."
# Out:
# "......Now Taking 'Average Cost for two' as Target."

# %%
#separating features and label for the Second Target Variable 'Average Cost for two'
x=df.drop("Average Cost for two",axis=1)
y=df["Average Cost for two"]

# %%
#Feature Scaling using Standard Scalarization
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City  Locality  \
# 0         -0.277386         0.052689     11.390428 -0.498280 -1.603037
# 1         -0.278877        -0.226145     11.390428 -0.498280 -0.280920
# 2         -0.279356        -0.355245     11.390428 -0.381656 -1.189281
# 3         -0.277289         0.491312     11.390428 -0.381656  0.541836
# 4         -0.277759         0.876496     11.390428 -0.381656  0.541836
# ...             ...              ...           ...       ...       ...
# 8560      -0.290304        -0.674292     11.505165 -2.131029  1.340813
# 8561      -0.290398         1.656387     11.505165 -2.131029  1.431174
# 8562       1.056489         0.847925     11.505165 -2.131029  1.459708
# 8563      -0.290372         0.545809     11.505165 -2.131029  1.540557
# 8564       1.062922         0.817766     11.505165 -2.131029  1.540557
#
#       Longitude  Latitude  Cuisines   Currency  Has Table booking  \
# ...

# %%
#Checking Variance Inflation Factor(VIF)
#finding variance inflation factor in each scaled col 
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) 
for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values             Features
# 0     1.431308        Restaurant ID
# 1     1.009673      Restaurant Name
# 2     1.434058         Country Code
# 3     1.054338                 City
# 4     1.038082             Locality
# 5    32.864032            Longitude
# 6    33.204718             Latitude
# 7     1.024254             Cuisines
# 8     1.331294             Currency
# 9     1.511685    Has Table booking
# 10    1.221325  Has Online delivery
# 11    1.014873    Is delivering now
# 12    1.901535          Price range
# 13    3.342217     Aggregate rating
# 14    1.874438          Rating text
# 15    3.560346                Votes

# %%
"""Here we can see the multicollinearity issue. VIF values of Longitude and Latitude >10 therefore we need to drop one column
which have the greater VIF values. so we dropping Latitude feature here."""
# Out:
# 'Here we can see the multicollinearity issue. VIF values of Longitude and Latitude >10 therefore we need to drop one column\nwhich have the greater VIF values. so we dropping Latitude feature here.'

# %%
x.drop("Latitude",axis=1,inplace=True)

# %%
#Again checking vif values to confirm wether the multicollinearity still exists or not
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) 
for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF Values             Features
# 0     1.427157        Restaurant ID
# 1     1.009616      Restaurant Name
# 2     1.101412         Country Code
# 3     1.051809                 City
# 4     1.037999             Locality
# 5     1.068450            Longitude
# 6     1.024051             Cuisines
# 7     1.073389             Currency
# 8     1.471343    Has Table booking
# 9     1.198161  Has Online delivery
# 10    1.014727    Is delivering now
# 11    1.876737          Price range
# 12    3.339543     Aggregate rating
# 13    1.861469          Rating text
# 14    3.511053                Votes

# %%
"Now No multicollinearity Issues."
# Out:
# 'Now No multicollinearity Issues.'

# %%
#creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is ",maxAccu,"on Random state",maxRs)
# Out:
# Maximum r2 score is  0.8250112579877014 on Random state 84

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRs)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_LR)))
# Out:
# R2_score: 0.8250112579877014
# R2_score on training data: 79.74477783584364
# Mean Absolute Error: 0.6675234423985945
# Mean Squared Error: 0.7533585221852301
# Root Mean Squared Error: 0.8170210783074048

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.8880847494308794
# R2_score on training data: 98.33202099147188
# Mean Absolute Error: 0.5206324488900728
# Mean Squared Error: 0.48181561173127757
# Root Mean Squared Error: 0.7215486462395122

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_etr))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_etr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_etr))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_etr)))
# Out:
# R2_score: 0.8794943702161486
# R2_score on training data: 100.0
# Mean Absolute Error: 0.5381911124633947
# Mean Squared Error: 0.5187987645661356
# Root Mean Squared Error: 0.7336150983065948

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on training data:',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred_GBR)))
# Out:
# R2_score: 0.8854323822270682
# R2_score on training data: 89.19203313982673
# Mean Absolute Error: 0.542526361936023
# Mean Squared Error: 0.4932345373945946
# Root Mean Squared Error: 0.7365638885636622

# %%
#Checking Cross validation score
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.03601903  0.82449651  0.79210389  0.80413075 -0.31112744]
# 0.42912454921429005
# Difference between R2 score and cross validation score is : 39.58867087734113

# %%
score1=cross_val_score(RFR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [-0.1398304   0.88274163  0.86768402  0.90153954  0.70447712]
# 0.6433223830298544
# Difference between R2 score and cross validation score is : 24.4762366401025

# %%
score2=cross_val_score(etr,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_etr)-score2.mean())*100)
# Out:
# [0.4706632  0.87282211 0.85318073 0.89305793 0.76973487]
# 0.7718917663486109
# Difference between R2 score and cross validation score is : 10.760260386753773

# %%
score3=cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is :",(r2_score(y_test,pred_GBR)-score3.mean())*100)
# Out:
# [-0.25072379  0.86759643  0.8567542   0.88395299  0.70041404]
# 0.611598773115408
# Difference between R2 score and cross validation score is : 27.383360911166022

# %%
"""From the difference between both R2 score and cross validation score computed on R2 score we 
can conclude that Extra Trees Regressor as our best fitting and best performing model"""
# Out:
# 'From the difference between both R2 score and cross validation score computed on R2 score we \ncan conclude that Extra Trees Regressor as our best fitting and best performing model'

# %%
#Hyper parameter tunning
from sklearn.model_selection import GridSearchCV
param = { 
        'n_estimators': range(50,100,200),
        'min_samples_leaf': range(5,10,15),
        'min_samples_split': range(2,4,8),
    
        }
gscv=GridSearchCV(etr,param_grid=param, cv=5,n_jobs=-1,scoring='r2')
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(), n_jobs=-1,
#              param_grid={'min_samples_leaf': range(5, 10, 15),
#                          'min_samples_split': range(2, 4, 8),
#                          'n_estimators': range(50, 100, 200)},
#              scoring='r2')

# %%
gscv.best_params_
# Out:
# {'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 50}

# %%
model=ExtraTreesRegressor(min_samples_leaf=5,n_estimators=50,min_samples_split=2)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_absolute_error(y_test,pred)))
# Out:
# R2_score: 0.8800120727629374
# Mean Absolute Error: 0.5406409097728232
# Mean Squared Error: 0.5165699604665387
# Root Mean Squared Error: 0.7352828773831356

# %%
filename='avg_cost.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('avg_cost.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 88.00120727629374

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                0         1         2         3         4         5     \
# Predicted  8.734638  8.440984  8.630926  8.851012  6.690979  6.888132
# Original   8.879040  8.434327  8.193213  8.662391  7.368063  7.368063
#
#                6         7         8          9     ...      2560      2561  \
# Predicted  8.493887  5.730933  6.107365  12.824397  ...  8.345079  6.879072
# Original   8.434327  5.313293  5.848035  13.572088  ...  8.879040  7.663094
#
#                2562       2563      2564      2565      2566      2567  \
# Predicted  5.294967  11.367934  8.311746  8.037412  8.883259  8.597746
# Original   4.641589  10.772173  9.283178  7.937005  7.937005  8.662391
#
#                2568       2569
# Predicted  8.409009  10.396062
# Original   8.434327  10.626586
#
# [2 rows x 2570 columns]

# %%
>>From the difference between both R2 score and cross validation score computed on R2 score we can conclude that 
  Random Forest Regressor is our best fitting and best performing model
>>The best score is 97.55% for prediction of Price range of Restaurant.
                                AND
>>From the difference between both R2 score and cross validation score computed on R2 score we can conclude that 
  Extra Trees Regressor is our best fitting and best performing model
>>The best score is 88.00% for prediction of Average cost for two person.
